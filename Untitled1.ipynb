# %% [markdown]
# <a href="https://colab.research.google.com/github/charmith2007-max/char/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
a=20
b=10
sum=a+b
print(sum)
# Out:
# 30

# %%
a="hello"
print(a)
# Out:
# hello

# %%
print("enter the number")
a=int(input())
print("enter the number")
b=int(input())
print(a+b)
# Out:
# enter the number
# 5
# enter the number
# 3
# 8

# %%
print(1,2,3,4,sep="*")
print(1,2,3,4)
# Out:
# 1*2*3*4
# 1 2 3 4

# %%
a=100
b=10
print(a>b)
print(a,b,sep="+")
print(a<b)
# Out:
# True
# 100+10
# False

# %%
print("Hello KMIT")
print("hello\tkmit")
print("Python\nis a high level,general-purpose\nProgramming Language")
x=100
print(x)
x=15.145
print("the value of x =",x)
a=10
b=20
print(f"sum of {a} and {b} is",a+b)
c=30
print(f"a ={a},b ={b},c ={c}")
a=12.215467
b=2.356478
print(f"sum of {a} and {b} is {a+b:.2f}")
# Out:
# Hello KMIT
# hello	kmit
# Python
# is a high level,general-purpose
# Programming Language
# 100
# the value of x = 15.145
# sum of 10 and 20 is 30
# a =10,b =20,c =30
# sum of 12.215467 and 2.356478 is 14.57
